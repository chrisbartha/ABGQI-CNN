# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/CQuinn8-ABGQI-CNN-93420d1/5_ABGQI-CNN_deployment/
# Out:
# /content/drive/MyDrive/Colab Notebooks/CQuinn8-ABGQI-CNN-93420d1/5_ABGQI-CNN_deployment

# %%
#!/usr/bin/env python
# coding: utf-8

# # Build spectrograms from wavs
# - Uses ROI_generation.yml env
# - As is: builds 30 spectrogram pngs in directory with wav file name from a common wav directory (e.g., a filder with 20 wav files will result in 20 mel spec folders, each with 30 pngs)


import matplotlib
matplotlib.use('Agg')
matplotlib.rcParams['figure.dpi'] = 72 #dpi manually set to match S2L machines

import matplotlib.pyplot as plt
import numpy as np
import librosa
import librosa.display
import pandas as pd
import IPython.display as display

import pathlib
import os
import joblib
import sys
import glob

# S2L functions
from melspec_functions import *

# %%
# User inputs
# os.chdir('published_github_repo') # where github repo is cloned
out_dir = r'~/content/drive/MyDrive/Colab\ Notebooks/CQuinn8-ABGQI-CNN-93420d1/5_ABGQI-CNN_deployment/data/melspecs/' # parent mel spec folder to write to
audio_dir = '/content/drive/Shareddrives/BioSoundSCape_ABG/wavs/' # folder containing wav files to read
print("Results parent dir = ", out_dir)
print('Audio wav dir = ', audio_dir)
# Out:
# Results parent dir =  ~/content/drive/MyDrive/Colab\ Notebooks/CQuinn8-ABGQI-CNN-93420d1/5_ABGQI-CNN_deployment/data/melspecs/
# Audio wav dir =  /content/drive/Shareddrives/BioSoundSCape_ABG/wavs/

# %%
# find out how many wavs to process
audio_files = [os.path.normpath(i) for i in glob.glob(audio_dir + '*')]
print("Length of audio file list:", len(audio_files))
# Out:
# Length of audio file list: 2666

# %%
# PROCESSING: MELSPEC GENERATION
# iterate through each wav file
for no in range(len(audio_files)):
    print(audio_files[no])
    #wav_nm = audio_files[no].split('\\')[-1] # get wav name

    wav_nm = os.path.basename(audio_files[no])
    wav_nm = wav_nm.split('.')[0] # remove .wav from name

    print('wav:', wav_nm)
    mel_store = os.path.join(out_dir, wav_nm) # melspec folder with wav name
    wav_pth = os.path.join(audio_dir, wav_nm + '.WAV') # full wav path name

    print(out_dir, wav_nm)

    print('\nwav file', no, ':', wav_pth)
    print('Mel dir name:', mel_store)

    if(os.path.exists(mel_store)):
        print(mel_store,'Already exists!')

        # check if there are 30 mels
        mel_files = glob.glob(mel_store + "/*.png")
        print("There are ",len(mel_files), "melspecs in the directory")

        # if there are not 30 specs, build them
        if len(mel_files) != 30 :
            print("calculating mel specs")
            clipped_wav = clip_wav(wav_path = wav_pth, clip_duration = 2.000, sample_rate= 22050, offset = None)
            create_melSpecs(audio_samples = clipped_wav, FMIN = 0, FMAX = 11025, HOP_SIZE = 128, N_MELS = 128, N_FFT = 1024+512,
                              sample_rate = 22050, save_pth = mel_store, mel_fname = "", offset = False)

        else:
            print("The directory is up to date")
    else:
        os.mkdir(mel_store)

        # even seconds (e.g. 0, 2, ..., 58)
        clipped_wav = clip_wav(wav_path = wav_pth, clip_duration = 2.000, sample_rate= 22050, offset = None)
        create_melSpecs(audio_samples = clipped_wav, FMIN = 0, FMAX = 11025, HOP_SIZE = 128, N_MELS = 128, N_FFT = 1024+512,
                            sample_rate = 22050, save_pth = mel_store, mel_fname = "", offset = False)
# Out:
# /content/drive/Shareddrives/BioSoundSCape_ABG/wavs/s2lam135_230809_2023-08-10_12-30.WAV
# wav: s2lam135_230809_2023-08-10_12-30
# ~/content/drive/MyDrive/Colab\ Notebooks/CQuinn8-ABGQI-CNN-93420d1/5_ABGQI-CNN_deployment/data/melspecs/ s2lam135_230809_2023-08-10_12-30
#
# wav file 0 : /content/drive/Shareddrives/BioSoundSCape_ABG/wavs/s2lam135_230809_2023-08-10_12-30.WAV
# Mel dir name: ~/content/drive/MyDrive/Colab\ Notebooks/CQuinn8-ABGQI-CNN-93420d1/5_ABGQI-CNN_deployment/data/melspecs/s2lam135_230809_2023-08-10_12-30
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-ccf6a49ea6ed> in <cell line: 3>()
#      35     else:
#      36         get_ipython().run_line_magic('pwd', '')
# ---> 37         os.mkdir(mel_store)
#      38
#      39         # even seconds (e.g. 0, 2, ..., 58)
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/content/drive/MyDrive/Colab\\ Notebooks/CQuinn8-ABGQI-CNN-93420d1/5_ABGQI-CNN_deployment/data/melspecs/s2lam135_230809_2023-08-10_12-30'

# %%
x, sr = librosa.load('/content/drive/Shareddrives/BioSoundSCape_ABG/wavs/s2lam135_230809_2023-08-10_12-30.wav')
# Out:
# <ipython-input-28-49998be0fda4>:1: UserWarning: PySoundFile failed. Trying audioread instead.
#   x, sr = librosa.load('/content/drive/Shareddrives/BioSoundSCape_ABG/wavs/s2lam135_230809_2023-08-10_12-30.wav')
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     174         try:
# --> 175             y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     176
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in __soundfile_load(path, offset, duration, dtype)
#     207         # Otherwise, create the soundfile object
# --> 208         context = sf.SoundFile(path)
#     209
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     657                                          format, subtype, endian)
# --> 658         self._file = self._open(file, mode_int, closefd)
#     659         if set(mode).issuperset('r+') and self.seekable():
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in _open(self, file, mode_int, closefd)
#    1215             err = _snd.sf_error(file_ptr)
# -> 1216             raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
#    1217         if mode_int == _snd.SFM_WRITE:
#
# LibsndfileError: Error opening '/content/drive/Shareddrives/BioSoundSCape_ABG/wavs/s2lam135_230809_2023-08-10_12-30.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-49998be0fda4> in <cell line: 1>()
# ----> 1 x, sr = librosa.load('/content/drive/Shareddrives/BioSoundSCape_ABG/wavs/s2lam135_230809_2023-08-10_12-30.wav')
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     181                     "PySoundFile failed. Trying audioread instead.", stacklevel=2
#     182                 )
# --> 183                 y, sr_native = __audioread_load(path, offset, duration, dtype)
#     184             else:
#     185                 raise exc
#
# <decorator-gen-119> in __audioread_load(path, offset, duration, dtype)
#
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py in __wrapper(func, *args, **kwargs)
#      57             stacklevel=3,  # Would be 2, but the decorator adds a level
#      58         )
# ---> 59         return func(*args, **kwargs)
#      60
#      61     return decorator(__wrapper)
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in __audioread_load(path, offset, duration, dtype)
#     237     else:
#     238         # If the input was not an audioread object, try to open it
# --> 239         reader = audioread.audio_open(path)
#     240
#     241     with reader as input_file:
#
# /usr/local/lib/python3.10/dist-packages/audioread/__init__.py in audio_open(path, backends)
#     125     for BackendClass in backends:
#     126         try:
# --> 127             return BackendClass(path)
#     128         except DecodeError:
#     129             pass
#
# /usr/local/lib/python3.10/dist-packages/audioread/rawread.py in __init__(self, filename)
#      57     """
#      58     def __init__(self, filename):
# ---> 59         self._fh = open(filename, 'rb')
#      60
#      61         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/Shareddrives/BioSoundSCape_ABG/wavs/s2lam135_230809_2023-08-10_12-30.wav'
